# %% [markdown]
# ### Week 8 - Recurrent Neural Networks for time series

# %% [markdown]
# This notebook is heavily inspired by Andre Guernon work, that can be found here: https://github.com/ageron/handson-ml2/blob/master/15_processing_sequences_using_rnns_and_cnns.ipynb. Check it out!

# %% [markdown]
# ## Setup

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
    IS_COLAB = True
except Exception:
    IS_COLAB = False

# TensorFlow ≥2.0 is required
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

if not tf.test.is_gpu_available():
    print("No GPU was detected. LSTMs and CNNs can be very slow without a GPU.")
    if IS_COLAB:
        print("Go to Runtime > Change runtime and select a GPU hardware accelerator.")

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)
tf.random.set_seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "rnn"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)
# Out:
# WARNING:tensorflow:From <ipython-input-1-606ac0e8de3d>:21: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# No GPU was detected. LSTMs and CNNs can be very slow without a GPU.

# %% [markdown]
# ## Basic RNNs

# %% [markdown]
# ### Generate the Dataset
#
# The function below generates as many time series as specified in `batch_size`, each of length `n_steps`. All series are univariate, i.e. only one value is produced per time step in each series. The function returns a NumPy array of shape `[batch size, time steps, 1]`. Each series is the addition of two sine waves of fixed amplitudes but random frequency, plus somenoise.

# %%
def generate_time_series(batch_size, n_steps):
    freq1, freq2, offsets1, offsets2 = np.random.rand(4, batch_size, 1)
    time = np.linspace(0, 1, n_steps)
    series = 0.5 * np.sin((time - offsets1) * (freq1 * 10 + 10))  #   wave 1
    series += 0.2 * np.sin((time - offsets2) * (freq2 * 20 + 20)) # + wave 2
    series += 0.1 * (np.random.rand(batch_size, n_steps) - 0.5)   # + noise
    return series[..., np.newaxis].astype(np.float32)

# %%
np.random.seed(42)

n_steps = 50
series = generate_time_series(10000, n_steps + 1)
X_train, y_train = series[:7000, :n_steps], series[:7000, -1]
X_valid, y_valid = series[7000:9000, :n_steps], series[7000:9000, -1]
X_test, y_test = series[9000:, :n_steps], series[9000:, -1]

# %%
X_train.shape, y_train.shape
# Out:
# ((7000, 50, 1), (7000, 1))

# %%
def plot_series(series, y=None, y_pred=None, x_label="$t$", y_label="$x(t)$"):
    plt.plot(series, ".-")
    if y is not None:
        plt.plot(n_steps, y, "bx", markersize=10)
    if y_pred is not None:
        plt.plot(n_steps, y_pred, "ro")
    plt.grid(True)
    if x_label:
        plt.xlabel(x_label, fontsize=16)
    if y_label:
        plt.ylabel(y_label, fontsize=16, rotation=0)
    plt.hlines(0, 0, 100, linewidth=1)
    plt.axis([0, n_steps + 1, -1, 1])

fig, axes = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(12, 4))
for col in range(3):
    plt.sca(axes[col])
    plot_series(X_valid[col, :, 0], y_valid[col, 0],
                y_label=("$x(t)$" if col==0 else None))
plt.show()

# %% [markdown]
# ### 2. Try some predictors

# %% [markdown]
# ### 2.1 Naive predictions
# We just predict the last observed value.

# %%
y_pred = X_valid[:, -1] # last observed value
np.mean(keras.losses.mean_squared_error(y_valid, y_pred))
# Out:
# 0.020211367

# %%
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()

# %% [markdown]
# ### 2.2 Linear Prediction - Perceptron

# %%
np.random.seed(42)
tf.random.set_seed(42)

n_net = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[50, 1]),
    keras.layers.Dense(1)
])

n_net.compile(
    loss="mse", 
    optimizer="adam", 
    metrics=[keras.metrics.RootMeanSquaredError()]
)
history = n_net.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 1s 148us/sample - loss: 0.1004 - root_mean_squared_error: 0.3169 - val_loss: 0.0559 - val_root_mean_squared_error: 0.2365
# Epoch 2/20
# 7000/7000 [==============================] - 0s 56us/sample - loss: 0.0386 - root_mean_squared_error: 0.1966 - val_loss: 0.0269 - val_root_mean_squared_error: 0.1640
# Epoch 3/20
# 7000/7000 [==============================] - 0s 57us/sample - loss: 0.0205 - root_mean_squared_error: 0.1432 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1273
# Epoch 4/20
# 7000/7000 [==============================] - 0s 57us/sample - loss: 0.0133 - root_mean_squared_error: 0.1153 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1086
# Epoch 5/20
# 7000/7000 [==============================] - 0s 65us/sample - loss: 0.0104 - root_mean_squared_error: 0.1017 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0992
# Epoch 6/20
# 7000/7000 [==============================] - 0s 59us/sample - loss: 0.0089 - root_mean_squared_error: 0.0945 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0933
# Epoch 7/20
# 7000/7000 [==============================] - 0s 59us/sample - loss: 0.0080 - root_mean_squared_error: 0.0895 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0886
# Epoch 8/20
# 7000/7000 [==============================] - 0s 53us/sample - loss: 0.0073 - root_mean_squared_error: 0.0852 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0843
# Epoch 9/20
# 7000/7000 [==============================] - 0s 61us/sample - loss: 0.0066 - root_mean_squared_error: 0.0814 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0809
# Epoch 10/20
# 7000/7000 [==============================] - 0s 54us/sample - loss: 0.0061 - root_mean_squared_error: 0.0784 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0784
# Epoch 11/20
# 7000/7000 [==============================] - 0s 53us/sample - loss: 0.0058 - root_mean_squared_error: 0.0760 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0761
# Epoch 12/20
# 7000/7000 [==============================] - 0s 57us/sample - loss: 0.0054 - root_mean_squared_error: 0.0737 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0744
# Epoch 13/20
# 7000/7000 [==============================] - 0s 52us/sample - loss: 0.0052 - root_mean_squared_error: 0.0719 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0722
# Epoch 14/20
# 7000/7000 [==============================] - 0s 53us/sample - loss: 0.0050 - root_mean_squared_error: 0.0705 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0703
# Epoch 15/20
# 7000/7000 [==============================] - 0s 60us/sample - loss: 0.0048 - root_mean_squared_error: 0.0692 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0686
# Epoch 16/20
# 7000/7000 [==============================] - 0s 55us/sample - loss: 0.0046 - root_mean_squared_error: 0.0681 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0678
# Epoch 17/20
# 7000/7000 [==============================] - 0s 56us/sample - loss: 0.0045 - root_mean_squared_error: 0.0673 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0669
# Epoch 18/20
# 7000/7000 [==============================] - 0s 62us/sample - loss: 0.0044 - root_mean_squared_error: 0.0664 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0680
# Epoch 19/20
# 7000/7000 [==============================] - 0s 65us/sample - loss: 0.0043 - root_mean_squared_error: 0.0654 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0655
# Epoch 20/20
# 7000/7000 [==============================] - 0s 54us/sample - loss: 0.0042 - root_mean_squared_error: 0.0646 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0644

# %%
mse, rmse = n_net.evaluate(X_valid, y_valid, verbose=0)
mse, rmse
# Out:
# (0.004145486254245043, 0.064385444)

# %%
def plot_learning_curves(loss, val_loss):
    plt.plot(np.arange(len(loss)) + 0.5, loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)) + 1, val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.axis([1, 20, 0, 0.05])
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %% [markdown]
# It looks  as if the system has been trained nicely. Let's see the predictions.

# %%
y_pred = n_net.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()

# %% [markdown]
# ### 2.3 A Simple RNN
#
# This is really the simplest conceivable RNN. There is no need to specify the length of the input sequences here as an RNN can process any number of time points (hence the first input dimension is set to `None`). By default, the SimpleRNN layer uses the $tanh()$ activation functionn

# %%
np.random.seed(42)
tf.random.set_seed(42)

n_net = keras.models.Sequential([
    keras.layers.SimpleRNN(1, input_shape=[None, 1])
])

optimizer = keras.optimizers.Adam(lr=0.005)
n_net.compile(loss=keras.metrics.mean_squared_error, 
              optimizer=optimizer, 
              metrics=[keras.metrics.RootMeanSquaredError()])
history = n_net.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 5s 731us/sample - loss: 0.0972 - root_mean_squared_error: 0.3118 - val_loss: 0.0491 - val_root_mean_squared_error: 0.2216
# Epoch 2/20
# 7000/7000 [==============================] - 5s 667us/sample - loss: 0.0372 - root_mean_squared_error: 0.1929 - val_loss: 0.0298 - val_root_mean_squared_error: 0.1727
# Epoch 3/20
# 7000/7000 [==============================] - 4s 603us/sample - loss: 0.0255 - root_mean_squared_error: 0.1597 - val_loss: 0.0220 - val_root_mean_squared_error: 0.1483
# Epoch 4/20
# 7000/7000 [==============================] - 4s 602us/sample - loss: 0.0200 - root_mean_squared_error: 0.1412 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1334
# Epoch 5/20
# 7000/7000 [==============================] - 4s 640us/sample - loss: 0.0167 - root_mean_squared_error: 0.1294 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1233
# Epoch 6/20
# 7000/7000 [==============================] - 4s 634us/sample - loss: 0.0147 - root_mean_squared_error: 0.1212 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1162
# Epoch 7/20
# 7000/7000 [==============================] - 4s 554us/sample - loss: 0.0133 - root_mean_squared_error: 0.1154 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1113
# Epoch 8/20
# 7000/7000 [==============================] - 4s 539us/sample - loss: 0.0124 - root_mean_squared_error: 0.1115 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1080
# Epoch 9/20
# 7000/7000 [==============================] - 4s 607us/sample - loss: 0.0119 - root_mean_squared_error: 0.1090 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1062
# Epoch 10/20
# 7000/7000 [==============================] - 4s 545us/sample - loss: 0.0116 - root_mean_squared_error: 0.1077 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1049
# Epoch 11/20
# 7000/7000 [==============================] - 4s 541us/sample - loss: 0.0114 - root_mean_squared_error: 0.1070 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1047
# Epoch 12/20
# 7000/7000 [==============================] - 4s 539us/sample - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1046
# Epoch 13/20
# 7000/7000 [==============================] - 4s 581us/sample - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1045
# Epoch 14/20
# 7000/7000 [==============================] - 4s 573us/sample - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1042
# Epoch 15/20
# 7000/7000 [==============================] - 4s 527us/sample - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1042
# Epoch 16/20
# 7000/7000 [==============================] - 4s 538us/sample - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1042
# Epoch 17/20
# 7000/7000 [==============================] - 4s 564us/sample - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1043
# Epoch 18/20
# 7000/7000 [==============================] - 4s 569us/sample - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1043
# Epoch 19/20
# 7000/7000 [==============================] - 4s 535us/sample - loss: 0.0114 - root_mean_squared_error: 0.1068 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1044
# Epoch 20/20
# 7000/7000 [==============================] - 4s 550us/sample - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1043

# %%
mse, rmse = n_net.evaluate(X_valid, y_valid, verbose=0)
mse, rmse
# Out:
# (0.010885455444455147, 0.104333386)

# %%
y_pred = n_net.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()

# %% [markdown]
# This is better than the naive approach but not as good as the linear Perceptron model. However, not that for each neuron, a linear model has one parameter per input (i.e. per time step), plus a bias term (in our case, that was 51 parameters, but in general it would be $N_{time\_steps} + 1$). Coversely, for each recurrent neuron in the simple RNN, there’s 1 parameter per input and 1 per hidden state dimension  plus a bias term. In this  simple RNN there is just a neuron, hence 1 hidden state dimension: that’s a total of 3 parameters. That scales much better, for time series with thousands or millions of time points.

# %% [markdown]
# ### 2.4 Deep RNNs

# %% [markdown]
# **Exercise 01:** create a neural network with 3 recurrent layers:
# * two layers of 20 recurrent units each
# * one output layer with the appropriate number of recurrent neurons
#
# Compile the network setting the appropriate loss function, the Adam optimizer, and RMSE ad an additional metric. Then train the network for the same number of epochs as the previous models and save the results in the `history` object.

# %%
np.random.seed(42)
tf.random.set_seed(42)

# Write your solution completing the ellipses in the code here:

n_net = ...

n_net.compile(...)
history = ...
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-4c473c28984d> in <module>
#       6 n_net = ...
#       7
# ----> 8 n_net.compile(...)
#       9 history = ...
#
# AttributeError: 'ellipsis' object has no attribute 'compile'

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_pred = n_net.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()

# %% [markdown]
# ## 3. Forecasting Several Steps Ahead

# %% [markdown]
# Until now we have only predicted the value at the next time step. Using the same network(s) we could have predicted values _n_ steps ahead just by changing the targets appropriately (e.g., to predict 10 steps ahead, change the targets to be the value 10 steps ahead instead of 1 step ahead). But what can we do if our goal is to predict the next _n_ values? There are basically two options here.
#
#  1) use the model we already trained, make it predict the next value, then add that value to the inputs (acting as if this predicted value had actually occurred), and use the network again to predict the following value, and go on like this:

# %%
np.random.seed(43) # not 42, as it would give the first series in the train set

series = generate_time_series(1, n_steps + 10)
X_new, Y_new = series[:, :n_steps], series[:, n_steps:]
X = X_new
for step_ahead in range(10):
    y_pred_one = n_net.predict(X[:, step_ahead:])[:, np.newaxis, :]
    X = np.concatenate([X, y_pred_one], axis=1)

Y_pred = X[:, n_steps:]

# %%
Y_pred.shape

# %%
def plot_multiple_forecasts(X, Y, Y_pred):
    n_steps = X.shape[1]
    ahead = Y.shape[1]
    plot_series(X[0, :, 0])
    plt.plot(np.arange(n_steps, n_steps + ahead), Y[0, :, 0], "ro-", label="Actual")
    plt.plot(np.arange(n_steps, n_steps + ahead), Y_pred[0, :, 0], "bx-", label="Forecast", markersize=10)
    plt.axis([0, n_steps + ahead, -1, 1])
    plt.legend(fontsize=14)

plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %% [markdown]
# 2) Train an RNN to predict all 10 next values at once. It is still possible to use a sequence-to-vector model, but this will produce 10 values instead of 1. For it to work we need to modify the targets to be vectors containing the next 10 values:

# %%
series = generate_time_series(10000, n_steps + 10)
X_train, Y_train = series[:7000, :n_steps], series[:7000, -10:, 0]
X_valid, Y_valid = series[7000:9000, :n_steps], series[7000:9000, -10:, 0]
X_test, Y_test = series[9000:, :n_steps], series[9000:, -10:, 0]

# %% [markdown]
# Now we need the output layer to have 10 units rather than 1:

# %%
model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20),
    keras.layers.Dense(10)
])

# %% [markdown]
# **Exercise 02:** Compile and train the network defined above. Evaluate its performance

# %%
# Write your solution here:
